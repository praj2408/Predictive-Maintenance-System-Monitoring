# %%
import pandas as pd

# %%
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv("preprocessed_csv.csv")

# %%
X = df.drop(["Machine failure", "type_of_failure"], axis=1)

# %%
y = df["Machine failure"]

# %%
X
# Out:
#        Type  TWF  HDF  PWF  OSF  RNF  Rotational speed [rpm]  Torque [Nm]  \
# 0       1.0    0    0    0    0    0                0.222934     0.535714
# 1       0.0    0    0    0    0    0                0.139697     0.583791
# 2       0.0    0    0    0    0    0                0.192084     0.626374
# 3       0.0    0    0    0    0    0                0.154249     0.490385
# 4       0.0    0    0    0    0    0                0.139697     0.497253
# ...     ...  ...  ...  ...  ...  ...                     ...          ...
# 57907   1.0    1    0    0    0    0                0.526649     0.215713
# 57908   2.0    1    0    0    0    0                0.196063     0.509599
# 57909   0.0    1    0    0    0    0                0.176288     0.505579
# 57910   0.0    1    0    0    0    0                0.129250     0.499476
# 57911   1.0    1    0    0    0    0                0.147699     0.566789
#
#        Tool wear [min]  Air temperature [c]  Process temperature [c]
# 0             0.000000             0.304348                 0.358025
# 1             0.011858             0.315217                 0.370370
# 2             0.019763             0.304348                 0.345679
# 3             0.027668             0.315217                 0.358025
# 4             0.035573             0.315217                 0.370370
# ...                ...                  ...                      ...
# 57907         0.913215             0.582407                 0.738526
# 57908         0.863595             0.661389                 0.611683
# 57909         0.875856             0.227373                 0.321660
# 57910         0.850685             0.257532                 0.345679
# 57911         0.873910             0.538582                 0.735180
#
# [57912 rows x 11 columns]
